# %%
import os
from datasets import load_from_disk
from transformers import (
    GPT2LMHeadModel,
    GPT2Tokenizer, 
)

os.environ["CUDA_VISIBLE_DEVICES"] = "0"

DATA_PATH = "/home/ubuntu/data/dataset/wikitext_dataset"
dataset = load_from_disk(DATA_PATH)
train_data = dataset['train']
valid_data = dataset['validation']

MODEL_PATH = "/home/ubuntu/data/model/gpt2_model"
tokenizer = GPT2Tokenizer.from_pretrained(MODEL_PATH)
if tokenizer.pad_token is None:
    tokenizer.pad_token = tokenizer.eos_token
model = GPT2LMHeadModel.from_pretrained(
        MODEL_PATH,
        torch_dtype=torch.bfloat16 if torch.cuda.is_available() else torch.float32,
    ).to(DEVICE)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 9
#       6 valid_data = dataset['validation']
#       8 MODEL_PATH = "/home/ubuntu/data/model/gpt2_model"
# ----> 9 tokenizer, model = load_tokenizer_and_model(MODEL_PATH)
#
# NameError: name 'load_tokenizer_and_model' is not defined
